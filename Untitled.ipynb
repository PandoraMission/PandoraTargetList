# %%
import pandoratargetlist as ptl

from pandoratargetlist.targets import Target

print(ptl.__version__)
# Out:
# In preparation for Gaia DR4, the Gaia archive is in evolution. Unfortunately, it may be unstable at times and particular types of queries may time out. Please consider registering for a user account (https://www.cosmos.esa.int/web/gaia-users/register). For questions or advice, please contact the Gaia helpdesk (https://www.cosmos.esa.int/web/gaia/gaia-helpdesk).
# 1.0.0

# %%
exo_list = {
    "GJ 367 b",
    "TOI-500 b",
    "TOI-561 b",
    "L 98-59 b",
    "GJ 486 b",
    "HD 213885 b",
    "K2-141 b",
    "L 98-59 c"
}

exos = dict()
for exo in exo_list:
    print(f"Working on {exo}.")
    exos[exo] = Target.from_name('WASP-69 b', 'auxiliary-exoplanet')
    exos[exo].show()
# Out:
# Working on TOI-500 b.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 15
#      13 for exo in exo_list:
#      14     print(f"Working on {exo}.")
# ---> 15     exos[exo] = Target.from_name('WASP-69 b', 'auxiliary-exoplanet')
#      16     exos[exo].show()
#
# File C:\Gits\PandoraTargetList\.venv\lib\site-packages\pandoratargetlist\targets.py:121, in Target.from_name(name, category, **kwargs)
#     119 @staticmethod
#     120 def from_name(name, category, **kwargs):
# --> 121     return Target(name=name, category=category, **kwargs)
#
# File C:\Gits\PandoraTargetList\.venv\lib\site-packages\pandoratargetlist\targets.py:86, in Target.__init__(self, name, category, info_dict, author, explicit)
#      82 self.name = name.replace(" ", "_")
#      84 if not explicit:
#      85     # Check to see if file already exists and adjust name to match
# ...
